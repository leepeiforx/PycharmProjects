# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\bolat\Desktop\crime.csv',encoding='GBK')
head = df[:100]

crime_list = pd.read_csv(r'C:\Users\bolat\Desktop\offense_codes.csv',
                         encoding='GBK')

# %%
df = df.merge(crime_list,how='left',left_on='OFFENSE_CODE',right_on='CODE')

# %%
df2 = df['NAME'].value_counts()[:10]

#df['NAME'].value_counts()[:5].plot(kind='barh')

sns.barplot(x=df2.values,y=df2.index,palette='GnBu_d')

plt.show()
